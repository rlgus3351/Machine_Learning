# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
train = pd.read_csv('./age_train_csv', index_col='no')
test = pd.read_csv('./age_test_csv',index_col='no')

# %%
train
# Out:
#        age          workclass  fnlwgt education       marital-status  \
# no
# 1       25            Private  219199    level2             Divorced
# 2       39            Private   52978    level3             Divorced
# 3       35            Private  196899    level3        Never-married
# 4       64            Private  135527    level3             Divorced
# 5       24            Private   60783    level3   Married-civ-spouse
# ...    ...                ...     ...       ...                  ...
# 29301   20            Private  100605    level2        Never-married
# 29302   21            Private  372636    level2        Never-married
# 29303   18   Self-emp-not-inc  258474    level2        Never-married
# 29304   33            Private  157446    level2        Never-married
# 29305   65                  ?   94809    level2              Widowed
#
#                occupation    relationship                 race      sex  \
# no
# ...

# %%
test
# Out:
#        age  fnlwgt  capital-gain  capital-loss  hours-per-week  workclass_ ?  \
# no
# 29306   18  245274             0             0              16             1
# 29307   29   83003             0             0              40             0
# 29308   45   35136             0             0              40             0
# 29309   42   64631             0             0              40             0
# 29310   41  195821             0          1902              40             0
# ...    ...     ...           ...           ...             ...           ...
# 48838   45  116789             0             0              60             0
# 48839   48  185079             0             0              50             0
# 48840   63  117473          4386             0              40             0
# 48841   18  150817             0             0              20             0
# 48842   31  341632             0             0              46             0
#
# ...

# %%
train['relationship'].value_counts()
# Out:
#  Husband           11769
#  Not-in-family      7637
#  Own-child          4554
#  Unmarried          3071
#  Wife               1370
#  Other-relative      904
# Name: relationship, dtype: int64

# %%
sns.countplot(train,x='relationship',hue='income')
plt.show()

# %%
train['relationship'].value_counts()
# Out:
#  Husband           11769
#  Not-in-family      7637
#  Own-child          4554
#  Unmarried          3071
#  Wife               1370
#  Other-relative      904
# Name: relationship, dtype: int64
