# %%
# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

import os, sys, gc, warnings, random, datetime

import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score, f1_score, precision_recall_curve, accuracy_score
from sklearn.model_selection import KFold, StratifiedKFold

import lightgbm as lgb
import xgboost as xgb


from matplotlib import pyplot as plt
import seaborn as sns

# %%
def read_data(na_values=' ?', target='income', drop_cols=['education-num']):
    train = pd.read_csv('../data/train.csv', na_values=na_values)
    y = train.pop(target)
    train.drop(drop_cols, axis='columns', inplace=True)
    print('train.shape:', train.shape)
    display(train.head())
    
    test = pd.read_csv('../data/test.csv', na_values=na_values)
    test.drop(drop_cols, axis='columns', inplace=True)
    print('test.shape:', test.shape)
    display(test.head())
    
    return train, test, y

# %%
train, test, y = read_data()
# Out:
# train.shape: (29305, 14)
#    no  age workclass  fnlwgt      education       marital-status  \
# 0   1   25   Private  219199           11th             Divorced
# 1   2   39   Private   52978   Some-college             Divorced
# 2   3   35   Private  196899      Bachelors        Never-married
# 3   4   64   Private  135527      Assoc-voc             Divorced
# 4   5   24   Private   60783   Some-college   Married-civ-spouse
#
#            occupation    relationship                 race      sex  \
# 0   Machine-op-inspct   Not-in-family                White     Male
# 1       Other-service   Not-in-family                White   Female
# 2   Handlers-cleaners   Not-in-family   Asian-Pac-Islander   Female
# 3        Tech-support   Not-in-family                White   Female
# 4    Transport-moving         Husband                White     Male
#
#    capital-gain  capital-loss  hours-per-week  native-country
# 0             0             0              40   United-States
# 1             0          1721              55   United-States
# 2             0             0              50           Haiti
# 3             0             0              40   United-States
# 4             0             0              70   United-States
# test.shape: (19537, 14)
#       no  age          workclass  fnlwgt      education       marital-status  \
# 0  29306   18                NaN  245274   Some-college        Never-married
# 1  29307   29            Private   83003        HS-grad   Married-civ-spouse
# 2  29308   45            Private   35136      Bachelors   Married-civ-spouse
# 3  29309   42   Self-emp-not-inc   64631      Bachelors   Married-civ-spouse
# 4  29310   41            Private  195821      Doctorate   Married-civ-spouse
#
#          occupation relationship    race      sex  capital-gain  capital-loss  \
# 0               NaN    Own-child   White     Male             0             0
# 1     Other-service         Wife   White   Female             0             0
# 2      Tech-support      Husband   Black     Male             0             0
# 3   Exec-managerial      Husband   White     Male             0             0
# 4   Exec-managerial         Wife   White   Female             0          1902
#
#    hours-per-week  native-country
# 0              16   United-States
# 1              40   United-States
# 2              40   United-States
# 3              40   United-States
# 4              40   United-States

# %%
y.shape
# Out:
# (29305,)

# %%
train.isna().sum()
# Out:
# no                   0
# age                  0
# workclass         1663
# fnlwgt               0
# education            0
# marital-status       0
# occupation        1668
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     495
# dtype: int64

# %%
test.isna().sum()
# Out:
# no                   0
# age                  0
# workclass         1136
# fnlwgt               0
# education            0
# marital-status       0
# occupation        1141
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     362
# dtype: int64

# %%
features = [col for col in train.columns if col != 'no']
features
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country']

# %%
pd.concat([train,y], axis=1)[train[features].duplicated(keep=False)].sort_values(features)
# Out:
#           no  age workclass  fnlwgt      education       marital-status  \
# 7839    7840   17   Private  153021           12th        Never-married
# 12266  12267   17   Private  153021           12th        Never-married
# 17505  17506   19   Private  130431        5th-6th        Never-married
# 20332  20333   19   Private  130431        5th-6th        Never-married
# 5123    5124   19   Private  139466   Some-college        Never-married
# 6524    6525   19   Private  139466   Some-college        Never-married
# 787      788   19   Private  251579   Some-college        Never-married
# 16146  16147   19   Private  251579   Some-college        Never-married
# 17250  17251   19       NaN  167428   Some-college        Never-married
# 21015  21016   19       NaN  167428   Some-college        Never-married
# 2220    2221   20   Private  107658   Some-college        Never-married
# 11043  11044   20   Private  107658   Some-college        Never-married
# 8077    8078   20       NaN  203353   Some-college        Never-married
# 16031  16032   20       NaN  203353   Some-college        Never-married
# 7487    7488   21   Private  250051   Some-college        Never-married
# 17895  17896   21   Private  250051   Some-college        Never-married
# 9791    9792   22   Private  137876   Some-college        Never-married
# 19666  19667   22   Private  137876   Some-college        Never-married
# 1681    1682   23   Private  107882      Bachelors        Never-married
# 19647  19648   23   Private  107882      Bachelors        Never-married
# 3241    3242   23   Private  250630      Bachelors        Never-married
# 25813  25814   23   Private  250630      Bachelors        Never-married
# 18836  18837   25   Private  195994        1st-4th        Never-married
# 21443  21444   25   Private  195994        1st-4th        Never-married
# 15268  15269   28   Private  274679        Masters        Never-married
# 16355  16356   28   Private  274679        Masters        Never-married
# 18844  18845   34   Private  169583        Masters        Never-married
# 24765  24766   34   Private  169583        Masters        Never-married
# 9467    9468   38   Private  207202        HS-grad   Married-civ-spouse
# 28750  28751   38   Private  207202        HS-grad   Married-civ-spouse
# 3108    3109   39   Private  138192      Bachelors   Married-civ-spouse
# 14609  14610   39   Private  138192      Bachelors   Married-civ-spouse
# 316      317   39   Private  184659        HS-grad   Married-civ-spouse
# 21745  21746   39   Private  184659        HS-grad   Married-civ-spouse
# 12733  12734   42   Private  204235   Some-college   Married-civ-spouse
# 25175  25176   42   Private  204235   Some-college   Married-civ-spouse
# 9587    9588   43   Private  195258        HS-grad   Married-civ-spouse
# 19887  19888   43   Private  195258        HS-grad   Married-civ-spouse
# 16714  16715   46   Private  173243        HS-grad   Married-civ-spouse
# 25460  25461   46   Private  173243        HS-grad   Married-civ-spouse
# 24351  24352   46   Private  235646        HS-grad   Married-civ-spouse
# 27889  27890   46   Private  235646        HS-grad   Married-civ-spouse
# 4871    4872   47   Private  199058   Some-college   Married-civ-spouse
# 10450  10451   47   Private  199058   Some-college   Married-civ-spouse
# 22875  22876   90   Private   52386   Some-college        Never-married
# 27139  27140   90   Private   52386   Some-college        Never-married
#
#                occupation    relationship                 race      sex  \
# 7839                Sales       Own-child                White   Female
# 12266               Sales       Own-child                White   Female
# 17505     Farming-fishing   Not-in-family                White     Male
# 20332     Farming-fishing   Not-in-family                White     Male
# 5123                Sales       Own-child                White   Female
# 6524                Sales       Own-child                White   Female
# 787         Other-service       Own-child                White     Male
# 16146       Other-service       Own-child                White     Male
# 17250                 NaN       Own-child                White     Male
# 21015                 NaN       Own-child                White     Male
# 2220         Tech-support   Not-in-family                White   Female
# 11043        Tech-support   Not-in-family                White   Female
# 8077                  NaN       Own-child                White   Female
# 16031                 NaN       Own-child                White   Female
# 7487       Prof-specialty       Own-child                White   Female
# 17895      Prof-specialty       Own-child                White   Female
# 9791      Protective-serv   Not-in-family                White     Male
# 19666     Protective-serv   Not-in-family                White     Male
# 1681         Adm-clerical       Own-child                White   Female
# 19647        Adm-clerical       Own-child                White   Female
# 3241                Sales   Not-in-family                White   Female
# 25813               Sales   Not-in-family                White   Female
# 18836     Priv-house-serv   Not-in-family                White   Female
# 21443     Priv-house-serv   Not-in-family                White   Female
# 15268      Prof-specialty   Not-in-family                White     Male
# 16355      Prof-specialty   Not-in-family                White     Male
# 18844     Exec-managerial   Not-in-family                White   Female
# 24765     Exec-managerial   Not-in-family                White   Female
# 9467    Machine-op-inspct         Husband                White     Male
# 28750   Machine-op-inspct         Husband                White     Male
# 3108         Craft-repair         Husband                White     Male
# 14609        Craft-repair         Husband                White     Male
# 316     Machine-op-inspct         Husband                White     Male
# 21745   Machine-op-inspct         Husband                White     Male
# 12733      Prof-specialty         Husband                White     Male
# 25175      Prof-specialty         Husband                White     Male
# 9587         Craft-repair         Husband                White     Male
# 19887        Craft-repair         Husband                White     Male
# 16714        Craft-repair         Husband                White     Male
# 25460        Craft-repair         Husband                White     Male
# 24351        Craft-repair         Husband                White     Male
# 27889        Craft-repair         Husband                White     Male
# 4871       Prof-specialty         Husband                White     Male
# 10450      Prof-specialty         Husband                White     Male
# 22875       Other-service   Not-in-family   Asian-Pac-Islander     Male
# 27139       Other-service   Not-in-family   Asian-Pac-Islander     Male
#
#        capital-gain  capital-loss  hours-per-week  native-country  income
# 7839              0             0              20   United-States       0
# 12266             0             0              20   United-States       0
# 17505             0             0              36          Mexico       0
# 20332             0             0              36          Mexico       0
# 5123              0             0              25   United-States       0
# 6524              0             0              25   United-States       0
# 787               0             0              14   United-States       0
# 16146             0             0              14   United-States       0
# 17250             0             0              40   United-States       0
# 21015             0             0              40   United-States       0
# 2220              0             0              10   United-States       0
# 11043             0             0              10   United-States       0
# 8077              0             0              40   United-States       0
# 16031             0             0              40   United-States       0
# 7487              0             0              10   United-States       0
# 17895             0             0              10   United-States       0
# 9791              0             0              20   United-States       0
# 19666             0             0              20   United-States       0
# 1681              0             0              40   United-States       0
# 19647             0             0              40   United-States       0
# 3241              0             0              40   United-States       0
# 25813             0             0              40   United-States       0
# 18836             0             0              40       Guatemala       0
# 21443             0             0              40       Guatemala       0
# 15268             0             0              50   United-States       0
# 16355             0             0              50   United-States       0
# 18844             0             0              50   United-States       1
# 24765             0             0              50   United-States       0
# 9467              0             0              48   United-States       1
# 28750             0             0              48   United-States       1
# 3108              0             0              40   United-States       1
# 14609             0             0              40   United-States       0
# 316               0             0              40   United-States       0
# 21745             0             0              40   United-States       0
# 12733             0             0              40   United-States       1
# 25175             0             0              40   United-States       1
# 9587              0             0              40   United-States       1
# 19887             0             0              40   United-States       1
# 16714             0             0              40   United-States       0
# 25460             0             0              40   United-States       0
# 24351             0             0              40   United-States       0
# 27889             0             0              40   United-States       1
# 4871              0             0              40   United-States       1
# 10450             0             0              40   United-States       1
# 22875             0             0              35   United-States       0
# 27139             0             0              35   United-States       0

# %%
features = [col for col in test.columns if col != 'no']
test[test[features].duplicated(keep=False)].sort_values(features)
# Out:
#           no  age          workclass  fnlwgt      education  \
# 4299   33605   19            Private  146679   Some-college
# 14377  43683   19            Private  146679   Some-college
# 6952   36258   21            Private  243368      Preschool
# 14702  44008   21            Private  243368      Preschool
# 1322   30628   22                NaN  334593   Some-college
# 15520  44826   22                NaN  334593   Some-college
# 2081   31387   23            Private  240137        5th-6th
# 13999  43305   23            Private  240137        5th-6th
# 164    29470   25            Private  308144      Bachelors
# 6551   35857   25            Private  308144      Bachelors
# 1234   30540   29            Private   36440      Bachelors
# 13795  43101   29            Private   36440      Bachelors
# 4346   33652   31            Private  228873        HS-grad
# 4384   33690   31            Private  228873        HS-grad
# 11037  40343   44            Private  367749      Bachelors
# 17336  46642   44            Private  367749      Bachelors
# 78     29384   49            Private   31267        7th-8th
# 2659   31965   49            Private   31267        7th-8th
# 12594  41900   49   Self-emp-not-inc   43479   Some-college
# 15426  44732   49   Self-emp-not-inc   43479   Some-college
#
#             marital-status          occupation    relationship    race  \
# 4299         Never-married     Exec-managerial       Own-child   Black
# 14377        Never-married     Exec-managerial       Own-child   Black
# 6952         Never-married     Farming-fishing   Not-in-family   White
# 14702        Never-married     Farming-fishing   Not-in-family   White
# 1322         Never-married                 NaN   Not-in-family   White
# 15520        Never-married                 NaN   Not-in-family   White
# 2081         Never-married   Handlers-cleaners   Not-in-family   White
# 13999        Never-married   Handlers-cleaners   Not-in-family   White
# 164          Never-married        Craft-repair   Not-in-family   White
# 6551         Never-married        Craft-repair   Not-in-family   White
# 1234         Never-married        Adm-clerical   Not-in-family   White
# 13795        Never-married        Adm-clerical   Not-in-family   White
# 4346    Married-civ-spouse        Craft-repair         Husband   White
# 4384    Married-civ-spouse        Craft-repair         Husband   White
# 11037        Never-married      Prof-specialty   Not-in-family   White
# 17336        Never-married      Prof-specialty   Not-in-family   White
# 78      Married-civ-spouse        Craft-repair         Husband   White
# 2659    Married-civ-spouse        Craft-repair         Husband   White
# 12594   Married-civ-spouse        Craft-repair         Husband   White
# 15426   Married-civ-spouse        Craft-repair         Husband   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country
# 4299      Male             0             0              30   United-States
# 14377     Male             0             0              30   United-States
# 6952      Male             0             0              50          Mexico
# 14702     Male             0             0              50          Mexico
# 1322      Male             0             0              40   United-States
# 15520     Male             0             0              40   United-States
# 2081      Male             0             0              55          Mexico
# 13999     Male             0             0              55          Mexico
# 164       Male             0             0              40          Mexico
# 6551      Male             0             0              40          Mexico
# 1234    Female             0             0              40   United-States
# 13795   Female             0             0              40   United-States
# 4346      Male             0             0              40   United-States
# 4384      Male             0             0              40   United-States
# 11037   Female             0             0              45          Mexico
# 17336   Female             0             0              45          Mexico
# 78        Male             0             0              40   United-States
# 2659      Male             0             0              40   United-States
# 12594     Male             0             0              40   United-States
# 15426     Male             0             0              40   United-States

# %%
grouped_trn = pd.concat([train,y], axis=1).groupby(features)['income'].agg(['count','mean'])
grouped_trn.head()
grouped_trn_dup = grouped_trn[grouped_trn['count']>1].reset_index()
grouped_trn_dup
# Out:
#     age workclass  fnlwgt      education       marital-status  \
# 0    17   Private  153021           12th        Never-married
# 1    19   Private  130431        5th-6th        Never-married
# 2    19   Private  139466   Some-college        Never-married
# 3    19   Private  251579   Some-college        Never-married
# 4    20   Private  107658   Some-college        Never-married
# 5    21   Private  250051   Some-college        Never-married
# 6    22   Private  137876   Some-college        Never-married
# 7    23   Private  107882      Bachelors        Never-married
# 8    23   Private  250630      Bachelors        Never-married
# 9    25   Private  195994        1st-4th        Never-married
# 10   28   Private  274679        Masters        Never-married
# 11   34   Private  169583        Masters        Never-married
# 12   38   Private  207202        HS-grad   Married-civ-spouse
# 13   39   Private  138192      Bachelors   Married-civ-spouse
# 14   39   Private  184659        HS-grad   Married-civ-spouse
# 15   42   Private  204235   Some-college   Married-civ-spouse
# 16   43   Private  195258        HS-grad   Married-civ-spouse
# 17   46   Private  173243        HS-grad   Married-civ-spouse
# 18   46   Private  235646        HS-grad   Married-civ-spouse
# 19   47   Private  199058   Some-college   Married-civ-spouse
# 20   90   Private   52386   Some-college        Never-married
#
#             occupation    relationship                 race      sex  \
# 0                Sales       Own-child                White   Female
# 1      Farming-fishing   Not-in-family                White     Male
# 2                Sales       Own-child                White   Female
# 3        Other-service       Own-child                White     Male
# 4         Tech-support   Not-in-family                White   Female
# 5       Prof-specialty       Own-child                White   Female
# 6      Protective-serv   Not-in-family                White     Male
# 7         Adm-clerical       Own-child                White   Female
# 8                Sales   Not-in-family                White   Female
# 9      Priv-house-serv   Not-in-family                White   Female
# 10      Prof-specialty   Not-in-family                White     Male
# 11     Exec-managerial   Not-in-family                White   Female
# 12   Machine-op-inspct         Husband                White     Male
# 13        Craft-repair         Husband                White     Male
# 14   Machine-op-inspct         Husband                White     Male
# 15      Prof-specialty         Husband                White     Male
# 16        Craft-repair         Husband                White     Male
# 17        Craft-repair         Husband                White     Male
# 18        Craft-repair         Husband                White     Male
# 19      Prof-specialty         Husband                White     Male
# 20       Other-service   Not-in-family   Asian-Pac-Islander     Male
#
#     capital-gain  capital-loss  hours-per-week  native-country  count  mean
# 0              0             0              20   United-States      2   0.0
# 1              0             0              36          Mexico      2   0.0
# 2              0             0              25   United-States      2   0.0
# 3              0             0              14   United-States      2   0.0
# 4              0             0              10   United-States      2   0.0
# 5              0             0              10   United-States      2   0.0
# 6              0             0              20   United-States      2   0.0
# 7              0             0              40   United-States      2   0.0
# 8              0             0              40   United-States      2   0.0
# 9              0             0              40       Guatemala      2   0.0
# 10             0             0              50   United-States      2   0.0
# 11             0             0              50   United-States      2   0.5
# 12             0             0              48   United-States      2   1.0
# 13             0             0              40   United-States      2   0.5
# 14             0             0              40   United-States      2   0.0
# 15             0             0              40   United-States      2   1.0
# 16             0             0              40   United-States      2   1.0
# 17             0             0              40   United-States      2   0.0
# 18             0             0              40   United-States      2   0.5
# 19             0             0              40   United-States      2   1.0
# 20             0             0              35   United-States      2   0.0

# %%
train_dedup = train.drop_duplicates(features, keep='last')
y_dedup = y[train_dedup.index]
train_dedup.reset_index(drop=True, inplace=True)
y_dedup.reset_index(drop=True, inplace=True)
print(train_dedup.shape, y_dedup.shape)
train_dedup.head()
# Out:
# (29282, 14) (29282,)
#    no  age workclass  fnlwgt      education       marital-status  \
# 0   1   25   Private  219199           11th             Divorced
# 1   2   39   Private   52978   Some-college             Divorced
# 2   3   35   Private  196899      Bachelors        Never-married
# 3   4   64   Private  135527      Assoc-voc             Divorced
# 4   5   24   Private   60783   Some-college   Married-civ-spouse
#
#            occupation    relationship                 race      sex  \
# 0   Machine-op-inspct   Not-in-family                White     Male
# 1       Other-service   Not-in-family                White   Female
# 2   Handlers-cleaners   Not-in-family   Asian-Pac-Islander   Female
# 3        Tech-support   Not-in-family                White   Female
# 4    Transport-moving         Husband                White     Male
#
#    capital-gain  capital-loss  hours-per-week  native-country
# 0             0             0              40   United-States
# 1             0          1721              55   United-States
# 2             0             0              50           Haiti
# 3             0             0              40   United-States
# 4             0             0              70   United-States

# %%
def freq_encode_full(df1, df2, col, normalize=True):
    df = pd.concat([df1[col],df2[col]])
    vc = df.value_counts(dropna=False, normalize=normalize).to_dict()
    nm = col + '_FE_FULL'
    df1[nm] = df1[col].map(vc)
    df1[nm] = df1[nm].astype('float32')
    df2[nm] = df2[col].map(vc)
    df2[nm] = df2[nm].astype('float32')
    return nm

# %%
for df in [train_dedup,test]:
    df['workclass-occupation'] = df['workclass'] + '#' + df['occupation']
    df['workclass-education'] = df['workclass'] + '#' + df['education']
    df['occupation-education'] = df['occupation'] + '#' + df['education']
    df['marital-status-relationship'] = df['marital-status'] + '#' + df['relationship']
    df['race-sex'] = df['race'] + '#' + df['sex']
    #df['native_country_race'] = df['native_country'] + '#' + df['race']
    #df['workclass_na'] = df['workclass'].isna().astype(int)
    #df['occupation_na'] = df['occupation'].isna().astype(int)
    #df['native_country_na'] = df['native_country'].isna().astype(int)
    #df['na_cnt'] = df.isna().sum(axis=1)
    df['capital-margin'] = df['capital-gain'] - df['capital-loss']
    df['capital-total'] = df['capital-gain'] + df['capital-loss']
    df['capital-margin-flag'] = np.nan
    df.loc[df['capital-margin']==0, 'capital-margin-flag'] = 'zero'
    df.loc[df['capital-margin']>0, 'capital-margin-flag'] = 'positive'
    df.loc[df['capital-margin']<0, 'capital-margin-flag'] = 'negative'
    #df['fnlwgt_log'] = np.log1p(df['fnlwgt'])

# %%
df.columns
# Out:
# Index(['no', 'age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country',
#        'workclass-occupation', 'workclass-education', 'occupation-education',
#        'marital-status-relationship', 'race-sex', 'capital-margin',
#        'capital-total', 'capital-margin-flag'],
#       dtype='object')

# %%
cate_cols = []
# LABEL ENCODING
for col in train_dedup.columns:
    if (train_dedup[col].dtype.name == 'object' or test[col].dtype.name == 'object' \
        or train_dedup[col].nunique() < 300) and col != 'age':
        cate_cols.append(col)
        le = LabelEncoder()
        le.fit(list(train_dedup[col].values) + list(test[col].values))
        train_dedup[col] = le.transform(list(train_dedup[col].values))
        test[col] = le.transform(list(test[col].values))
        
print('categorical feature:', cate_cols)
# Out:
# categorical feature: ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'workclass-occupation', 'workclass-education', 'occupation-education', 'marital-status-relationship', 'race-sex', 'capital-margin', 'capital-total', 'capital-margin-flag']

# %%
for col in [col for col in cate_cols if col not in ['capital-gain','capital-loss','race']]:
    freq_encode_full(train_dedup, test, col)

# %%
remove_features = ['id','income']
features = [col for col in list(train_dedup) if col not in remove_features]
features
# Out:
# ['no',
#  'age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country',
#  'workclass-occupation',
#  'workclass-education',
#  'occupation-education',
#  'marital-status-relationship',
#  'race-sex',
#  'capital-margin',
#  'capital-total',
#  'capital-margin-flag',
#  'workclass_FE_FULL',
#  'education_FE_FULL',
#  'marital-status_FE_FULL',
#  'occupation_FE_FULL',
#  'relationship_FE_FULL',
#  'sex_FE_FULL',
#  'hours-per-week_FE_FULL',
#  'native-country_FE_FULL',
#  'workclass-occupation_FE_FULL',
#  'workclass-education_FE_FULL',
#  'occupation-education_FE_FULL',
#  'marital-status-relationship_FE_FULL',
#  'race-sex_FE_FULL',
#  'capital-margin_FE_FULL',
#  'capital-total_FE_FULL',
#  'capital-margin-flag_FE_FULL']

# %%
def make_xgb_prediction(train, y, test, features, model_params=None, folds=5):
    def xgb_f1_score(y_hat, data):
        y_true = data.get_label()
        y_hat = np.round(y_hat) 
        return 'f1', 1-f1_score(y_true, y_hat, average='micro')
    
    skf = StratifiedKFold(n_splits=folds, random_state=42, shuffle=True)
    
    x_train = train[features]
    x_test = test[features]

    y_preds = np.zeros(x_test.shape[0])
    y_oof = np.zeros(x_train.shape[0])
    score = 0

    feature_importance = pd.DataFrame()
    feature_importance['feature'] = features

    for fold, (tr_idx, val_idx) in enumerate(skf.split(x_train, y)):
        print(f'Fold: {fold+1}')

        x_tr, x_val = x_train.loc[tr_idx, features], x_train.loc[val_idx, features]
        y_tr, y_val = y[tr_idx], y[val_idx]

        print(x_tr.shape, x_val.shape)

        dtrain = xgb.DMatrix(x_tr, label=y_tr)
        dvalid = xgb.DMatrix(x_val, label=y_val)

        clf = xgb.train(
            model_params,
            dtrain,
            num_boost_round=10000, 
            evals=[(dtrain, 'train'), (dvalid, 'valid')],
            verbose_eval=200,
            early_stopping_rounds=100,
            feval=xgb_f1_score
        )

        #feature_importance[f'fold_{fold+1}'] = clf.get_score()

        y_pred_val = clf.predict(dvalid)

        y_oof[val_idx] = y_pred_val
        print(f"Fold {fold + 1} | F1 Score: {f1_score(y_val, np.round(y_pred_val), average='micro')}")

        score += f1_score(y_val, np.round(y_pred_val), average='micro') / folds
        y_preds += clf.predict(xgb.DMatrix(x_test)) / folds

        del x_tr, x_val, y_tr, y_val
        gc.collect()

    print(f"\nMean F1 score = {score}")
    print(f"OOF F1 score = {f1_score(y, np.round(y_oof), average='micro')}")
    
    return y_oof, y_preds, feature_importance

# %%
# xgb model params
xgb_params = {
    'objective': 'binary:logistic',
    'learning_rate': 0.1,
    'max_depth': 6,
    #'colsample_bytree': 0.8,
    'subsample': 0.8,
    'disable_default_eval_metric': 1,
    #'eval_metric': 'logloss',
    'seed': 42,
}

# %%
y_oof_xgb, y_preds_xgb, fi_xgb = make_xgb_prediction(train_dedup, y_dedup, test, features, \
                                                     model_params=xgb_params)
# Out:
# Fold: 1
# (23425, 38) (5857, 38)
# [0]	train-f1:0.24038	valid-f1:0.24040
# [100]	train-f1:0.89020	valid-f1:0.89005
# Fold 1 | F1 Score: 0.8796312105173297
# Fold: 2
# (23425, 38) (5857, 38)
# [0]	train-f1:0.24038	valid-f1:0.24040
# [100]	train-f1:0.89059	valid-f1:0.89056
# Fold 2 | F1 Score: 0.867167491890046
# Fold: 3
# (23426, 38) (5856, 38)
# [0]	train-f1:0.24042	valid-f1:0.24027
# [100]	train-f1:0.88918	valid-f1:0.89771
# Fold 3 | F1 Score: 0.8729508196721312
# Fold: 4
# (23426, 38) (5856, 38)
# [0]	train-f1:0.24037	valid-f1:0.24044
# [100]	train-f1:0.88901	valid-f1:0.88866
# Fold 4 | F1 Score: 0.8773907103825137
# Fold: 5
# (23426, 38) (5856, 38)
# [0]	train-f1:0.24037	valid-f1:0.24044
# [99]	train-f1:0.89128	valid-f1:0.89242
# Fold 5 | F1 Score: 0.8657786885245902
#
# Mean F1 score = 0.8725837841973221
# OOF F1 score = 0.872583839901646

# %%
sample_submission['income'] = y_preds

for ix, row in sample_submission.iterrows():
    if row['prediction'] > 0.5:
        sample_submission.loc[ix, 'prediction'] = 1
    else:
        sample_submission.loc[ix, 'prediction'] = 0

sample_submission = sample_submission.astype({"prediction": int})
sample_submission.to_csv('submission.csv', index=False)
